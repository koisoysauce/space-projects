# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('data/planets.csv')

# %%
df.shape
# Out:
# (9, 21)

# %%
df.dtypes
# Out:
# planet                           str
# mass                         float64
# diameter                       int64
# density                        int64
# gravity                      float64
# escape_velocity              float64
# rotation_period              float64
# length_of_day                float64
# distance_from_sun            float64
# perihelion                   float64
# aphelion                     float64
# orbital_period               float64
# orbital_velocity             float64
# orbital_inclination          float64
# orbital_eccentricity         float64
# obliquity_to_orbit           float64
# mean_temperature               int64
# surface_pressure                 str
# number_of_moons                int64
# has_ring_system                  str
# has_global_magnetic_field        str
# dtype: object

# %%
df.isnull().sum()
# Out:
# planet                       0
# mass                         0
# diameter                     0
# density                      0
# gravity                      0
# escape_velocity              0
# rotation_period              0
# length_of_day                0
# distance_from_sun            0
# perihelion                   0
# aphelion                     0
# orbital_period               0
# orbital_velocity             0
# orbital_inclination          0
# orbital_eccentricity         0
# obliquity_to_orbit           0
# mean_temperature             0
# surface_pressure             0
# number_of_moons              0
# has_ring_system              0
# has_global_magnetic_field    0
# dtype: int64

# %%
df.head(10)
# Out:
#     planet       mass  diameter  density  gravity  escape_velocity  \
# 0  Mercury     0.3300      4879     5427      3.7              4.3
# 1    Venus     4.8700     12104     5243      8.9             10.4
# 2    Earth     5.9700     12756     5514      9.8             11.2
# 3     Mars     0.6420      6792     3933      3.7              5.0
# 4  Jupiter  1898.0000    142984     1326     23.1             59.5
# 5   Saturn   568.0000    120536      687      9.0             35.5
# 6   Uranus    86.8000     51118     1271      8.7             21.3
# 7  Neptune   102.0000     49528     1638     11.0             23.5
# 8    Pluto     0.0146      2370     2095      0.7              1.3
#
#    rotation_period  length_of_day  distance_from_sun  perihelion  ...  \
# 0           1407.6         4222.6               57.9        46.0  ...
# 1          -5832.5         2802.0              108.2       107.5  ...
# 2             23.9           24.0              149.6       147.1  ...
# ...

# %%
df.describe()
# Out:
#               mass       diameter      density    gravity  escape_velocity  \
# count     9.000000       9.000000     9.000000   9.000000         9.000000
# mean    296.291844   44785.222222  3014.888889   8.733333        19.111111
# std     627.786429   52882.835414  1997.680620   6.402929        18.701968
# min       0.014600    2370.000000   687.000000   0.700000         1.300000
# 25%       0.642000    6792.000000  1326.000000   3.700000         5.000000
# 50%       5.970000   12756.000000  2095.000000   8.900000        11.200000
# 75%     102.000000   51118.000000  5243.000000   9.800000        23.500000
# max    1898.000000  142984.000000  5514.000000  23.100000        59.500000
#
#        rotation_period  length_of_day  distance_from_sun   perihelion  \
# count         9.000000       9.000000           9.000000     9.000000
# mean       -501.133333     808.944444        1781.077778  1580.322222
# std        2054.404636    1573.907925        2166.307838  1834.822760
# ...

# %%
# 1. Which planet has the most moons?
df1 = df.sort_values(by='number_of_moons', ascending=False)
df1.iloc[0]
# Out:
# planet                        Jupiter
# mass                           1898.0
# diameter                       142984
# density                          1326
# gravity                          23.1
# escape_velocity                  59.5
# rotation_period                   9.9
# length_of_day                     9.9
# distance_from_sun               778.6
# perihelion                      740.5
# aphelion                        816.6
# orbital_period                 4331.0
# orbital_velocity                 13.1
# orbital_inclination               1.3
# orbital_eccentricity            0.049
# obliquity_to_orbit                3.1
# mean_temperature                 -110
# surface_pressure             Unknown*
# number_of_moons                    79
# has_ring_system                   Yes
# has_global_magnetic_field         Yes
# Name: 4, dtype: object

# %%
# 2. Is there a relationship between planet size and number of moons?
df2 = df[['diameter', 'number_of_moons']].sort_values(by='diameter')
df2
# Out:
#    diameter  number_of_moons
# 8      2370                5
# 0      4879                0
# 3      6792                2
# 1     12104                0
# 2     12756                1
# 7     49528               14
# 6     51118               27
# 5    120536               62
# 4    142984               79

# %%
# 2. Plot diameter vs. moon count
diameters = np.array(df2['diameter'].to_list())
number_of_moons = np.array(df2['number_of_moons'].to_list())

plt.plot(diameters, number_of_moons, 'bo-')
plt.title('Moon Count vs Planet Diameter')
plt.xlabel('diameter (km)')
plt.ylabel('moon count')
plt.show()
df2['diameter'].corr(df2['number_of_moons'])

# There appears to be a positive linear correlation between the number of moons and planet diameter 
# with a correlation coefficient of 0.987
# However, due to the small sample size of n=9, we have no evidence of a relation between moon counts and planet diameter
# Out:
# np.float64(0.9865539302436789)

# %%
# 3. How does gravity compare across planets?
df3 = df.sort_values(by='gravity')
df3.head()
# Out:
#     planet     mass  diameter  density  gravity  escape_velocity  \
# 8    Pluto   0.0146      2370     2095      0.7              1.3
# 0  Mercury   0.3300      4879     5427      3.7              4.3
# 3     Mars   0.6420      6792     3933      3.7              5.0
# 6   Uranus  86.8000     51118     1271      8.7             21.3
# 1    Venus   4.8700     12104     5243      8.9             10.4
#
#    rotation_period  length_of_day  distance_from_sun  perihelion  ...  \
# 8           -153.3          153.3             5906.4      4436.8  ...
# 0           1407.6         4222.6               57.9        46.0  ...
# 3             24.6           24.7              227.9       206.6  ...
# 6            -17.2           17.2             2872.5      2741.3  ...
# 1          -5832.5         2802.0              108.2       107.5  ...
#
#    orbital_period  orbital_velocity  orbital_inclination  \
# 8         90560.0               4.7                 17.2
# ...

# %%
# 4. How long is a year on each planet relative to Earth?

# %%
# 5. What would I weigh on each planet?
